# %% [markdown]
# __Дисклеймер:__ Эти ноутбуки посвящены использованию JAX для решения различных задач глубинного обучения. Поэтому я не буду уделять внимание теоретическим аспектам, предполагая, что читатель уже обладает достаточными знаниями, чтобы понимать происходящее. Если есть вопросы или предложения, то их можно оставить в issues этого репозитория.
